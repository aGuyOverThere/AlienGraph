# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import numpy as np
from datetime import datetime as dt

plt.style.use('seaborn-v0_8-dark')

# %%
events = { 
    "events": [
        {
            "name": "Research into Psychoenergetics Started",
            "date": dt.strptime("01-01-1970", "%m-%d-%Y"),
            "location": "Ft. Meade, MD",
            "type": "+"
        },
        {
            "name": "Gondola Wish Program Created",
            "date": dt.strptime("01-01-1977", "%m-%d-%Y"),
            "location": "Ft. Meade, MD",
            "type": "+"
        },
        {
            "name": "Project Grill Flame Created",
            "date": dt.strptime("01-01-1978", "%m-%d-%Y"),
            "location": "Ft. Meade, MD",
            "type": "+"
        },
        {
            "name": "Gale Committee Created",
            "date": dt.strptime("12-01-1979", "%m-%d-%Y"),
            "location": "Ft. Meade, MD",
            "type": "+"
        },
        {
            "name": "Grill Flame Operationalized\n     R&D --> Operations",
            "date": dt.strptime("12-30-1979", "%m-%d-%Y"),
            "location": "Ft. Meade, MD",
            "type": "!"
        },
        {
            "name": "Grill Flame MOU (DIA, CIA, Army, Navy)",
            "date": dt.strptime("01-01-1981", "%m-%d-%Y"),
            "location": "Ft. Meade, MD",
            "type": "$"
        },
        {
            "name": "Project Grill Flame Closed\n     Perry Memorandom",
            "date": dt.strptime("11-01-1982", "%m-%d-%Y"),
            "location": "Ft. Meade, MD",
            "type": "-"
        },
        {
            "name": "Project Center Lane Created",
            "date": dt.strptime("12-01-1982", "%m-%d-%Y"),
            "location": "Ft. Meade, MD",
            "type": "+"
        },
        {
            "name": "Perry Memorandom Reversed",
            "date": dt.strptime("01-01-1983", "%m-%d-%Y"),
            "location": "Ft. Meade, MD",
            "type": "-"
        },
        {
            "name": "DIA Grill Flame Report",
            "date": dt.strptime("10-19-1983", "%m-%d-%Y"),
            "location": "Ft. Meade, MD",
            "type": "!"
        },
        {
            "name": "Project Sun Streak Created",
            "date": dt.strptime("01-01-1984", "%m-%d-%Y"),
            "location": "Ft. Meade, MD",
            "type": "+"
        },
        
        

    ]

}

# %%
names = [f"{x['type']} | {x['name']}\n{x['date'].strftime("%m-%d-%Y")}" for x in events['events']]
dates = [x['date'] for x in events['events']]
s = [-5, 5, -4, 4, -3, 3, -2, 2, -1, 1]
_s = [1, -1, 2, -2, 3, -3, 4, -4]
# Choose some nice levels
levels = np.tile(_s,
                 int(np.ceil(len(dates)/6)))[:len(dates)]

# Create figure and plot a stem plot with the date
fig, ax = plt.subplots(figsize=(18, 4), layout="constrained")
ax.set(title="U.S. Govenment Programs | Psychoenegetics & Remote Viewing")

ax.vlines(
    dates, 
    0, 
    levels, 
    color="tab:red"
    )  # The vertical stems.

ax.plot(
    dates, 
    np.zeros_like(dates), 
    "-o",
    color="k", 
    markerfacecolor="w",
    ) # Baseline and markers on it.

# annotate lines
for d, l, r in zip(dates, levels, names):
    ax.annotate(
                r, 
                xy=(d, l),
                xytext=(-3, np.sign(l)*3), 
                textcoords="offset points",
                horizontalalignment="center",
                verticalalignment="bottom" if l > 0 else "top"
                )

# format x-axis with 4-month intervals
ax.xaxis.set_major_locator(mdates.MonthLocator(interval=4))
ax.xaxis.set_major_formatter(mdates.DateFormatter("%b %Y"))
plt.setp(ax.get_xticklabels(), rotation=50, ha="right")

# remove y-axis and spines
ax.yaxis.set_visible(False)
ax.spines[["left", "top", "right"]].set_visible(False)
ax.margins(y=0.1)

plt.show()
